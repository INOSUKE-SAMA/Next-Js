# %% [markdown]
# <a href="https://colab.research.google.com/github/INOSUKE-SAMA/Next-Js/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bios=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/bios.csv")

# %%
display(bios)
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios["height_cm"]>220,["name","died_date","weight_kg"]]
# Out:
#                    name died_date  weight_kg
# 5673     Gunther Behnke       NaN      114.0
# 5781     Tommy Burleson       NaN      102.0
# 6978    Arvydas Sabonis       NaN      122.0
# 89070          Yao Ming       NaN      141.0
# 89075    Roberto Dueñas       NaN      137.0
# 120266     Zhang Zhaoxu       NaN      110.0

# %%
bios[(bios["height_cm"]>190)&(bios["born_country"]=="FRA")]
# Out:
#         athlete_id                name   born_date born_city  \
# 2974          2986     Patrice Aouissi  1966-02-24      Lyon
# 5640          5663    Philippe Baillet  1940-10-06  Bordeaux
# 5647          5670   Christian Baltzer  1936-07-05  Mulhouse
# 5703          5726        Éric Beugnot  1955-03-22    Cliron
# 5704          5727      Gregor Beugnot  1957-10-07    Cliron
# ...            ...                 ...         ...       ...
# 139364      142835  Guerschon Yabusele  1995-12-17     Dreux
# 139365      142836      Moustapha Fall  1992-02-23     Paris
# 139368      142839     Vincent Poirier  1993-10-17   Clamart
# 139466      142939     Trévor Clévenot  1994-06-28     Royan
# 144642      148337       Bastien Midol  1990-08-03    Annecy
#
#               born_region born_country     NOC  height_cm  weight_kg  \
# 2974                Rhône          FRA  France      192.0       81.0
# 5640              Gironde          FRA  France      193.0       92.0
# ...

# %%
bios[bios['name'].str.contains("Mark")]
# Out:
#         athlete_id                 name   born_date  \
# 222            223     László Markovits  1970-04-04
# 444            445       Markku Syrjälä  1955-05-12
# 568            570       Mark Blenkarne  1957-10-07
# 631            634   Mark Philippoussis  1976-11-07
# 632            635          Mark Smythe  1973-03-01
# ...            ...                  ...         ...
# 144557      148249     Markus Lauridsen  1991-02-28
# 144613      148305      Markus Granlund  1993-04-16
# 144925      148633  Markuss Vinogradovs  2002-05-27
# 145099      148812      Mark Kondratyuk  2003-09-03
# 145248      148967           Marko Daňo  1994-11-30
#
#                              born_city        born_region born_country  \
# 222     Ciudad de México (Mexico City)   Ciudad de México          MEX
# 444                            Kurikka    Etelä-Pohjanmaa          FIN
# 568                             London            England          GBR
# ...

# %%
bios[bios['name'].str.contains("Mark",case=False)]
# Out:
#         athlete_id                 name   born_date  \
# 222            223     László Markovits  1970-04-04
# 444            445       Markku Syrjälä  1955-05-12
# 568            570       Mark Blenkarne  1957-10-07
# 631            634   Mark Philippoussis  1976-11-07
# 632            635          Mark Smythe  1973-03-01
# ...            ...                  ...         ...
# 144613      148305      Markus Granlund  1993-04-16
# 144925      148633  Markuss Vinogradovs  2002-05-27
# 145099      148812      Mark Kondratyuk  2003-09-03
# 145248      148967           Marko Daňo  1994-11-30
# 145314      149036       Lucas Wallmark  1995-09-05
#
#                              born_city        born_region born_country  \
# 222     Ciudad de México (Mexico City)   Ciudad de México          MEX
# 444                            Kurikka    Etelä-Pohjanmaa          FIN
# 568                             London            England          GBR
# ...

# %%
bios[bios['name'].str.contains(r"^Mark\s",case=False ,na=False)]
# this shows only Mark.
# Out:
#         athlete_id                name   born_date  born_city  \
# 568            570      Mark Blenkarne  1957-10-07     London
# 631            634  Mark Philippoussis  1976-11-07  Melbourne
# 632            635         Mark Smythe  1973-03-01   Box Hill
# 639            642      Mark Woodforde  1965-09-23   Adelaide
# 658            661        Mark Knowles  1971-09-04     Nassau
# ...            ...                 ...         ...        ...
# 140408      143916          Mark Roche  1993-01-25        NaN
# 141964      145551        Mark Caljouw  1995-01-25        NaN
# 143732      147387     Mark Kolozsvary  1995-09-04     Eustis
# 144283      147969       Mark Barberio  1990-03-23   Montréal
# 145099      148812     Mark Kondratyuk  2003-09-03    Podolsk
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 568             England          GBR  Great Britain      183.0       70.0
# ...

# %%
bios[(bios["born_country"].isin(["USA","FRA","GBR"])) & (bios["name"].str.startswith("Mark"))]
# Out:
#         athlete_id             name   born_date   born_city  born_region  \
# 568            570   Mark Blenkarne  1957-10-07      London      England
# 1708          1715    Mark Hulstrøm  1965-12-28      London      England
# 3227          3239      Mark Kotsay  1975-12-02    Whittier   California
# 3383          3395     Mark Edwards  1963-09-15      London      England
# 3385          3397     Mark Elliott  1966-02-02  Wellington      England
# ...            ...              ...         ...         ...          ...
# 131262      134037   Mark Robertson  1984-12-30  Galashiels     Scotland
# 131273      134049      Mark Aldred  1987-04-18  Birmingham      England
# 135113      138252       Mark Engel  1991-10-01      Folsom   California
# 135179      138323   Mark Arcobello  1988-08-12     Milford  Connecticut
# 143732      147387  Mark Kolozsvary  1995-09-04      Eustis      Florida
#
#        born_country            NOC  height_cm  weight_kg died_date
# ...

# %%
bios.query('born_city == "Niort" and height_cm >=181.3 ')
# Out:
#        athlete_id                 name   born_date born_city  born_region  \
# 36722       37016     Vincent Lepvraud  1970-07-28     Niort  Deux-Sèvres
# 62981       63451  Patrick Rieupeyrout  1951-05-24     Niort  Deux-Sèvres
#
#       born_country     NOC  height_cm  weight_kg   died_date
# 36722          FRA  France      198.0       95.0         NaN
# 62981          FRA  France      182.0       72.0  2021-03-11
